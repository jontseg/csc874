# %%
import pandas as pd
import seaborn as sns
import nltk
import string
from nltk.corpus import stopwords
from nltk import word_tokenize
from sklearn.naive_bayes import MultinomialNB
from nltk.stem import SnowballStemmer
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
stopwords = stopwords.words("english")

# %%
df = pd.read_csv("data.csv", encoding='utf8')
rdf = pd.read_csv("reddit_politics.csv", encoding = 'utf8')
newsdf = pd.read_csv("Amalgamated_Data_File.csv")
newsdf.head()
# Out:
#   media_source        published_date  \
# 0      BlazeTV  2021-11-19T16:36:10Z
# 1      BlazeTV  2021-11-19T00:00:08Z
# 2      BlazeTV  2021-11-18T23:00:10Z
# 3      BlazeTV  2021-11-18T21:00:04Z
# 4      BlazeTV  2021-11-18T20:00:10Z
#
#                                                title     video_id  \
# 0  Rand Paul: Why do Democrats STILL IGNORE risky...  D1qPYh9SQFg
# 1  Room Goes SILENT When Sen. Kennedy Calls Biden...  j_Nkxoqatkg
# 2  Did MSNBC Go TOO FAR? Rittenhouse Judge Bans N...  xnK1ej1Vk0s
# 3  Lauren Boebert Exposes the Democrats' Disgusti...  4PYu1fjKj5Y
# 4    Is Biden Planning on DUMPING Kamala? | @LevinTV  e6KxYb8t350
#
#                                 Thumbnail_Default  \
# 0  https://i.ytimg.com/vi/D1qPYh9SQFg/default.jpg
# 1  https://i.ytimg.com/vi/j_Nkxoqatkg/default.jpg
# 2  https://i.ytimg.com/vi/xnK1ej1Vk0s/default.jpg
# 3  https://i.ytimg.com/vi/4PYu1fjKj5Y/default.jpg
# 4  https://i.ytimg.com/vi/e6KxYb8t350/default.jpg
#
#                                  Thumbnail_Standard  \
# 0  https://i.ytimg.com/vi/D1qPYh9SQFg/sddefault.jpg
# 1  https://i.ytimg.com/vi/j_Nkxoqatkg/sddefault.jpg
# 2  https://i.ytimg.com/vi/xnK1ej1Vk0s/sddefault.jpg
# 3  https://i.ytimg.com/vi/4PYu1fjKj5Y/sddefault.jpg
# 4  https://i.ytimg.com/vi/e6KxYb8t350/sddefault.jpg
#
#                                    Thumbnail_Max_Res   views    likes  \
# 0  https://i.ytimg.com/vi/D1qPYh9SQFg/maxresdefau...   10557   1961.0
# 1  https://i.ytimg.com/vi/j_Nkxoqatkg/maxresdefau...  179915  17350.0
# 2  https://i.ytimg.com/vi/xnK1ej1Vk0s/maxresdefau...   41916   3356.0
# 3  https://i.ytimg.com/vi/4PYu1fjKj5Y/maxresdefau...   23004   3001.0
# 4  https://i.ytimg.com/vi/e6KxYb8t350/maxresdefau...   23106   2234.0
#
#    dislikes  num_comments  duration
# 0       3.0         285.0  PT12M34S
# 1     119.0        4176.0   PT7M19S
# 2      34.0         455.0   PT44M7S
# 3      17.0         268.0   PT4M40S
# 4      17.0         301.0   PT9M58S

# %%
print(df.columns)
print(rdf.columns)
# Out:
# Index(['title', 'politicallean', 'score', 'id', 'subreddit', 'URL',
#        'numcomments', 'text', 'date'],
#       dtype='object')
# Index(['title', 'score', 'id', 'url', 'comms_num', 'created', 'body',
#        'timestamp'],
#       dtype='object')

# %%
#Cleaning Data

# removing punctuation
def remove_punct(text):
    return text.translate(str.maketrans('', '', string.punctuation))
df['no_punctuation'] = df['title'].apply(remove_punct)
df['no_punctuation']

rdf['no_punctuation'] = rdf['title'].apply(remove_punct)
rdf['no_punctuation']

newsdf['no_punctuation'] = newsdf['title'].apply(remove_punct)
newsdf['no_punctuation']
# Out:
# 0        Rand Paul Why do Democrats STILL IGNORE risky ...
# 1        Room Goes SILENT When Sen Kennedy Calls Biden ...
# 2        Did MSNBC Go TOO FAR Rittenhouse Judge Bans Ne...
# 3        Lauren Boebert Exposes the Democrats Disgustin...
# 4             Is Biden Planning on DUMPING Kamala  LevinTV
#                                ...
# 87394    WATCH VA Sec Shulkin discusses Veterans Educat...
# 87395    WATCH AG Sessions discusses sanctuary cities i...
# 87396    Vice President Pence responds to question on P...
# 87397    WATCH Funeral service for Heather Heyer who wa...
# 87398    Baltimore mayor addresses removal of Confedera...
# Name: no_punctuation, Length: 87399, dtype: object

# %%
df['no_punctuation_lowercase'] = df['no_punctuation'].apply(lambda x: x.lower())
df['no_punctuation_lowercase']

rdf['no_punctuation_lowercase'] = rdf['no_punctuation'].apply(lambda x: x.lower())
rdf['no_punctuation_lowercase']

newsdf['no_punctuation_lowercase'] = newsdf['no_punctuation'].apply(lambda x: x.lower())
newsdf['no_punctuation_lowercase']
# Out:
# 0        a right wing group in texas is making up fake ...
# 1        doj sues texas over gov abbott’s order for law...
# 2        from white evangelicals to qanon believers who...
# 3        desantis says he’ll sign order allowing parent...
# 4        show on the road in utah florida gov ron desan...
#                                ...
# 28058                                              comment
# 28059                                              comment
# 28060                                              comment
# 28061                                              comment
# 28062                                              comment
# Name: no_punctuation_lowercase, Length: 28063, dtype: object

# %%
# Removing stopwords
def remove_stopwords(text):
    global stopwords
    new = []
    #print(word_tokenize(text))
    for el in word_tokenize(text):
        if not el in stopwords:
            new.append(el)
    return ' '.join(new)

df['no_punctuation_no_stopwords'] = df['no_punctuation_lowercase'].apply(remove_stopwords)
df['no_punctuation_no_stopwords']

rdf['no_punctuation_no_stopwords'] = rdf['no_punctuation_lowercase'].apply(remove_stopwords)
rdf['no_punctuation_no_stopwords']

newsdf['no_punctuation_no_stopwords'] = newsdf['no_punctuation_lowercase'].apply(remove_stopwords)
newsdf['no_punctuation_no_stopwords']
# Out:
# 0        right wing group texas making fake black lives...
# 1        doj sues texas gov abbott ’ order law enforcem...
# 2        white evangelicals qanon believers ’ likely re...
# 3        desantis says ’ sign order allowing parents ig...
# 4        show road utah florida gov ron desantis rails ...
#                                ...
# 28058                                              comment
# 28059                                              comment
# 28060                                              comment
# 28061                                              comment
# 28062                                              comment
# Name: no_punctuation_no_stopwords, Length: 28063, dtype: object

# %%
# Stemming words. "speaker -> speak"
def stemm(text):
    stemmer = PorterStemmer(PorterStemmer.ORIGINAL_ALGORITHM)
    new = []
    for word in word_tokenize(text):
        new.append(stemmer.stem(word))
    return ' '.join(new)

df['stemmed'] = df['no_punctuation_no_stopwords'].apply(stemm)
df['stemmed']

rdf['stemmed'] = rdf['no_punctuation_no_stopwords'].apply(stemm)
rdf['stemmed']
# Out:
# 0        right wing group texa make fake black live mat...
# 1        doj sue texa gov abbott ’ order law enforc pul...
# 2        white evangel qanon believ ’ like refus covid ...
# 3        desanti sai ’ sign order allow parent ignor co...
# 4        show road utah florida gov ron desanti rail fa...
#                                ...
# 28058                                              comment
# 28059                                              comment
# 28060                                              comment
# 28061                                              comment
# 28062                                              comment
# Name: stemmed, Length: 28063, dtype: object

# %%
# Lemmatization

def lematize(text):
    stemmer = WordNetLemmatizer()
    new = []
    for word in word_tokenize(text):
        new.append(stemmer.lemmatize(word))
    return ' '.join(new)

df['lematized'] = df['no_punctuation_no_stopwords'].apply(lematize)
df['lematized']

rdf['lematized'] = rdf['no_punctuation_no_stopwords'].apply(lematize)
rdf = rdf[rdf.title != "comment"]
# Out:
#                                                title  score      id  \
# 0  A Right Wing Group in Texas Is Making up Fake ...    166  ov1ll3
# 1  DOJ sues Texas over Gov. Abbott’s order for la...     85  ouwc9i
# 2  From white evangelicals to QAnon believers, wh...     57  ouqkxi
# 3  DeSantis says he’ll sign order allowing parent...    269  oun2lc
# 4  Show on the road: In Utah, Florida Gov. Ron De...     31  ouipnz
#
#                                                  url  comms_num       created  \
# 0  https://www.vice.com/en/article/wx5bg5/blm-whi...         34  1.627710e+09
# 1  https://www.kxan.com/news/texas-politics/doj-s...         17  1.627688e+09
# 2  https://www.modbee.com/news/coronavirus/articl...         27  1.627671e+09
# 3  https://www.orlandosentinel.com/politics/os-ne...        138  1.627660e+09
# 4  https://www.tallahassee.com/story/news/politic...         28  1.627644e+09
#
#   body            timestamp  \
# 0  NaN  2021-07-31 08:35:47
# 1  NaN  2021-07-31 02:26:12
# 2  NaN  2021-07-30 21:45:09
# 3  NaN  2021-07-30 18:43:05
# 4  NaN  2021-07-30 14:21:54
#
#                                       no_punctuation  \
# 0  A Right Wing Group in Texas Is Making up Fake ...
# 1  DOJ sues Texas over Gov Abbott’s order for law...
# 2  From white evangelicals to QAnon believers who...
# 3  DeSantis says he’ll sign order allowing parent...
# 4  Show on the road In Utah Florida Gov Ron DeSan...
#
#                             no_punctuation_lowercase  \
# 0  a right wing group in texas is making up fake ...
# 1  doj sues texas over gov abbott’s order for law...
# 2  from white evangelicals to qanon believers who...
# 3  desantis says he’ll sign order allowing parent...
# 4  show on the road in utah florida gov ron desan...
#
#                          no_punctuation_no_stopwords  \
# 0  right wing group texas making fake black lives...
# 1  doj sues texas gov abbott ’ order law enforcem...
# 2  white evangelicals qanon believers ’ likely re...
# 3  desantis says ’ sign order allowing parents ig...
# 4  show road utah florida gov ron desantis rails ...
#
#                                              stemmed  \
# 0  right wing group texa make fake black live mat...
# 1  doj sue texa gov abbott ’ order law enforc pul...
# 2  white evangel qanon believ ’ like refus covid ...
# 3  desanti sai ’ sign order allow parent ignor co...
# 4  show road utah florida gov ron desanti rail fa...
#
#                                            lematized
# 0  right wing group texas making fake black life ...
# 1  doj sue texas gov abbott ’ order law enforceme...
# 2  white evangelicals qanon believer ’ likely ref...
# 3  desantis say ’ sign order allowing parent igno...
# 4  show road utah florida gov ron desantis rail f...

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# In TfidfVectorizer we consider overall document weightage
# of a word. It helps us in dealing with most frequent words.
# Using it we can penalize them. TfidfVectorizer weights the
# word counts by a measure of how often they appear in the documents.
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report

# %%
# Fitting lematized data
X_train_lema, X_test_lema, y_train_lema, y_test_lema = train_test_split(df['lematized'], df['politicallean'], random_state = 0)
model_lema = make_pipeline(TfidfVectorizer(), MultinomialNB())
model_lema.fit(X_train_lema, y_train_lema)
y_pred_lema = model_lema.predict(X_train_lema)

clf_report = classification_report(y_train_lema, y_pred_lema)
print('Classification report on train data')
print(clf_report)

y2_pred_lema = model_lema.predict(rdf.title)
print((y2_pred_lema == "Liberal").sum())
print((y2_pred_lema == "Conservative").sum())
# Out:
# Classification report on train data
#               precision    recall  f1-score   support
#
# Conservative       0.96      0.54      0.69      3395
#      Liberal       0.80      0.99      0.88      6245
#
#     accuracy                           0.83      9640
#    macro avg       0.88      0.77      0.79      9640
# weighted avg       0.86      0.83      0.82      9640
#
# 27755
# 308

# %%
y_pred_lema = model_lema.predict(X_test_lema)

clf_report = classification_report(y_test_lema,y_pred_lema)
print('Classification report on test data')
print(clf_report)
# Out:
# Classification report on test data
#               precision    recall  f1-score   support
#
# Conservative       0.82      0.33      0.48      1140
#      Liberal       0.72      0.96      0.83      2074
#
#     accuracy                           0.74      3214
#    macro avg       0.77      0.65      0.65      3214
# weighted avg       0.76      0.74      0.70      3214

# %%
# Fitting stemmed data
X_train_stem, X_test_stem, y_train_stem, y_test_stem = train_test_split(df['stemmed'], df['PoliticalLean'], random_state = 0)
model_stem = make_pipeline(TfidfVectorizer(), MultinomialNB())
model_stem.fit(X_train_stem, y_train_stem)
y_pred_stem = model_lema.predict(X_train_stem)

clf_report = classification_report(y_train_stem, y_pred_stem)
print('Classification report on train data')
print(clf_report)
# Out:
# Classification report on train data
#               precision    recall  f1-score   support
#
# Conservative       0.94      0.39      0.55      3395
#      Liberal       0.75      0.99      0.85      6245
#
#     accuracy                           0.78      9640
#    macro avg       0.84      0.69      0.70      9640
# weighted avg       0.81      0.78      0.75      9640

# %%
y_pred_stem = model_lema.predict(X_test_stem)

clf_report = classification_report(y_test_stem, y_pred_stem)
print('Classification report on test data')
print(clf_report)
# Out:
# Classification report on test data
#               precision    recall  f1-score   support
#
# Conservative       0.81      0.27      0.40      1140
#      Liberal       0.71      0.97      0.82      2074
#
#     accuracy                           0.72      3214
#    macro avg       0.76      0.62      0.61      3214
# weighted avg       0.74      0.72      0.67      3214
